# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in d:\anaconda\anaconda3\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.0 in d:\anaconda\anaconda3\lib\site-packages (from opencv-python) (1.21.5)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('C:/Users/Yash Phadke/OneDrive/Desktop/ML/Computer Vision/Vision_Tutorials + learning/test.jpg')

# %%
plt.imshow(img)

# %%
new_img  = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(6,6))
plt.imshow(new_img)

# %%
A = img 
b = id(A)

# %%
print(b)
# Out:
# 1796821794704

# %%
c = A.copy

# %%
print(id(c))
# Out:
# 1796830294480
